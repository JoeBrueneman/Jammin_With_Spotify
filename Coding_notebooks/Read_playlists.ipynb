# %% [markdown]
# **This notebook reads the json files containing the playlists and convert them into csv files to be updated to a PostgreSQL database**

# %%
import json
import os
import pandas as pd
from IPython.display import clear_output

# %%
# Convert the nested dictionaries in the initial json file to a flat row that is concatenated to the dataframe
def process_json_data(playlists):
  global playlist_tracks_df

  tracks_dic_df = pd.json_normalize(playlists, record_path=['tracks'], meta=['pid','name', 'num_tracks'])

  playlist_tracks_df = pd.concat([playlist_tracks_df, tracks_dic_df], ignore_index=True)

# %%
# Reads a group of json files for data extraction
def process_mpd(slices,kk): 
    count_slice=kk
    count_playlist=0
    for filename in sorted(slices):

        if filename.startswith("mpd.slice.") and filename.endswith(".json"):
            fullpath = os.sep.join(('../data/', filename))
            f = open(fullpath)
            js = f.read()
            f.close()
            mpd_slice = json.loads(js)
            for playlist in mpd_slice["playlists"]:
                print('slice='+str(count_slice)+';  playlist='+str(count_playlist))
                process_json_data(playlist)
                clear_output(wait=True)
                count_playlist +=1
        count_slice +=1

# %%
# To define the location of the JSON files
path_to_slices='../data/'
filenames = os.listdir(path_to_slices)

# %%
# To define the beginning of the slices to be read
k=0
k_end=1000
k_inc=10    # 10 is the recommended number of playlists to be concatenated into a single dataframe and saved as an individual csv file.
            # Anything longer will see a dramatic slow down caused by the concatenation process as the dataframe gets bigger.

for kk in range(k,k_end,k_inc):
    # To initialize the global dataframe
    playlist_tracks_df=pd.DataFrame()
    process_mpd(filenames[kk:kk+k_inc],kk)

    # To reorder the columns
    playlist_tracks_df=playlist_tracks_df.reindex(columns=['pid','name','num_tracks','pos','track_name','track_uri','artist_name','artist_uri','album_name','album_uri', 'duration_ms'])
    # To update the column names
    playlist_tracks_df=playlist_tracks_df.rename(columns={'pid':'playlist_id','name':'playlist_name','pos':'track_pos'})

    # To save the dataframe as a CSV file. 
    file_name='data/playlist_tracks_'+str(kk)+'_'+str(kk+k_inc-1)+'.csv'
    playlist_tracks_df.to_csv(file_name,index=False)

# %% [markdown]
# ---------------------------------------
# *** Testing section ***

# %%
# To visualize a single playlist
playlist_tracks_df=pd.read_csv('enter_path_to_file')
# playlist_tracks_df=pd.read_csv('../spotify_million_playlist_dataset/src/data_playlists/playlist_tracks_0_19.csv')
pid=0       # playlist number present in the csv file 
playlist_tracks_df[playlist_tracks_df['playlist_id']==pid]
# Out:
#     playlist_id playlist_name  num_tracks  track_pos  \
# 0             0    Throwbacks          52          0
# 1             0    Throwbacks          52          1
# 2             0    Throwbacks          52          2
# 3             0    Throwbacks          52          3
# 4             0    Throwbacks          52          4
# 5             0    Throwbacks          52          5
# 6             0    Throwbacks          52          6
# 7             0    Throwbacks          52          7
# 8             0    Throwbacks          52          8
# 9             0    Throwbacks          52          9
# 10            0    Throwbacks          52         10
# 11            0    Throwbacks          52         11
# 12            0    Throwbacks          52         12
# 13            0    Throwbacks          52         13
# 14            0    Throwbacks          52         14
# 15            0    Throwbacks          52         15
# 16            0    Throwbacks          52         16
# 17            0    Throwbacks          52         17
# 18            0    Throwbacks          52         18
# 19            0    Throwbacks          52         19
# 20            0    Throwbacks          52         20
# 21            0    Throwbacks          52         21
# 22            0    Throwbacks          52         22
# 23            0    Throwbacks          52         23
# 24            0    Throwbacks          52         24
# 25            0    Throwbacks          52         25
# 26            0    Throwbacks          52         26
# 27            0    Throwbacks          52         27
# 28            0    Throwbacks          52         28
# 29            0    Throwbacks          52         29
# 30            0    Throwbacks          52         30
# 31            0    Throwbacks          52         31
# 32            0    Throwbacks          52         32
# 33            0    Throwbacks          52         33
# 34            0    Throwbacks          52         34
# 35            0    Throwbacks          52         35
# 36            0    Throwbacks          52         36
# 37            0    Throwbacks          52         37
# 38            0    Throwbacks          52         38
# 39            0    Throwbacks          52         39
# 40            0    Throwbacks          52         40
# 41            0    Throwbacks          52         41
# 42            0    Throwbacks          52         42
# 43            0    Throwbacks          52         43
# 44            0    Throwbacks          52         44
# 45            0    Throwbacks          52         45
# 46            0    Throwbacks          52         46
# 47            0    Throwbacks          52         47
# 48            0    Throwbacks          52         48
# 49            0    Throwbacks          52         49
# 50            0    Throwbacks          52         50
# 51            0    Throwbacks          52         51
#
#                                       track_name  \
# 0     Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                          Toxic
# 2                                  Crazy In Love
# 3                                 Rock Your Body
# 4                                   It Wasn't Me
# 5                                          Yeah!
# 6                                         My Boo
# 7                                        Buttons
# 8                                    Say My Name
# 9                 Hey Ya! - Radio Mix / Club Mix
# 10                                   Promiscuous
# 11  Right Where You Want Me - Radio Edit Version
# 12                                Beautiful Soul
# 13                                       Leavin'
# 14                                        Me & U
# 15                                       Ice Box
# 16                                     Sk8er Boi
# 17                                       Run It!
# 18       Check On It - feat. Bun B and Slim Thug
# 19                              Jumpin', Jumpin'
# 20                               Soak Up The Sun
# 21                            Where Is The Love?
# 22                                   Stacy's Mom
# 23                                 Just The Girl
# 24                           Yo (Excuse Me Miss)
# 25                                     Year 3000
# 26                                     Lip Gloss
# 27               Everytime We Touch - Radio Edit
# 28                                   Whatcha Say
# 29                              Miss Independent
# 30                           Party In The U.S.A.
# 31                              The Great Escape
# 32                                        Replay
# 33                                       Forever
# 34                          Your Love Is My Drug
# 35                                        Closer
# 36                          One Less Lonely Girl
# 37                                  Paper Planes
# 38                                Mr. Brightside
# 39                          All The Small Things
# 40                                          Beep
# 41                              Somebody To Love
# 42                           Dirty Little Secret
# 43                                          Baby
# 44                              A Thousand Miles
# 45                               Livin on Sunday
# 46                                 See You Again
# 47        How Do You Sleep? - Featuring Ludacris
# 48                                    This Is Me
# 49                               My Happy Ending
# 50                              Check Yes Juliet
# 51                              The Great Escape
#
#                                track_uri               artist_name  \
# 0   spotify:track:0UaMYEvWZi0ZqiDOoHU3YI             Missy Elliott
# 28  spotify:artist:07YZf4WDAMNwqr4jfgOZ8y
# 29  spotify:artist:21E3waRsmPlU7jZsS13rcj
# 30  spotify:artist:5YGY8feqx7naU7z4HrwZM6
# 31  spotify:artist:0vWCyXMrrvMlCcepuOJaGI
# 32  spotify:artist:5tKXB9uuebKE34yowVaU3C
# 33  spotify:artist:7bXgB6jMjp9ATFy66eO08Z
# 34  spotify:artist:6LqNN22kT3074XbTVUrhzX
# 35  spotify:artist:21E3waRsmPlU7jZsS13rcj
# 36  spotify:artist:1uNFoZAHBGtllmzznpCI3s
# 37  spotify:artist:0QJIPDAEDILuo8AIq3pMuU
# 38  spotify:artist:0C0XlULifJtAgn6ZNCW2eu
# 39  spotify:artist:6FBDaR13swtiWwGhX1WQsP
# 40  spotify:artist:6wPhSqRtPu1UhRCDX5yaDJ
# 41  spotify:artist:1uNFoZAHBGtllmzznpCI3s
# 42  spotify:artist:3vAaWhdBR38Q02ohXqaNHT
# 43  spotify:artist:1uNFoZAHBGtllmzznpCI3s
# 44  spotify:artist:5ILrArfIV0tMURcHJN8Q07
# 45  spotify:artist:7vWBZm3sQ8yQvfV4nXxHXK
# 46  spotify:artist:5YGY8feqx7naU7z4HrwZM6
# 47  spotify:artist:2Hjj68yyUPiC0HKEOigcEp
# 48  spotify:artist:6S2OmqARrzebs0tKUEyXyp
# 49  spotify:artist:0p4nmQO2msCgU4IF37Wi3j
# 50  spotify:artist:3ao3jf5d70Tf4fPh2bnXVl
# 51  spotify:artist:0vWCyXMrrvMlCcepuOJaGI
#
#                                       album_name  \
# 0                                   The Cookbook
# 1                                    In The Zone
# 2   Dangerously In Love (Alben für die Ewigkeit)
# 3                                      Justified
# 4                                       Hot Shot
# 5                                    Confessions
# 6                                    Confessions
# 7                                            PCD
# 8                      The Writing's On The Wall
# 9                    Speakerboxxx/The Love Below
# 10                                         Loose
# 11                       Right Where You Want Me
# 12                                Beautiful Soul
# 13                         Departure - Recharged
# 14                                        Cassie
# 15                                            21
# 16                                        Let Go
# 17                                   Chris Brown
# 18                                         B'Day
# 19                     The Writing's On The Wall
# 20                                   C'Mon C'Mon
# 21                                      Elephunk
# 22            I've Never Done Anything Like This
# 23                    Greetings From Imrie House
# 24                                   Chris Brown
# 25                                Jonas Brothers
# 26                                     Lip Gloss
# 27                            Everytime We Touch
# 28                                  Jason Derulo
# 29                         Year Of The Gentleman
# 30                         The Time Of Our Lives
# 31                               Boys Like Girls
# 32                                        Replay
# 33               Exclusive - The Forever Edition
# 34                                        Animal
# 35                         Year Of The Gentleman
# 36                                      My World
# 37                                          Kala
# 38                                      Hot Fuss
# 39                            Enema Of The State
# 40                                           PCD
# 41                                     My Worlds
# 42                                    Move Along
# 43                                     My Worlds
# 44                                 Be Not Nobody
# 45                                      Red Road
# 46                                 See You Again
# 47                         Departure - Recharged
# 48                 Camp Rock Original Soundtrack
# 49                                 Under My Skin
# 50                                  We The Kings
# 51                               Boys Like Girls
#
#                                album_uri  duration_ms
# 0   spotify:album:6vV5UrXcfyQD1wu4Qo2I9K       226863
# 1   spotify:album:0z7pVBGOD7HCIB7S8eLkLI       198800
# 2   spotify:album:25hVFAxTlDvXbx2X2QkUkE       235933
# 3   spotify:album:6QPkyl04rXwTGlGlcYaRoW       267266
# 4   spotify:album:6NmFmPX56pcLBOFMhIiKvF       227600
# 5   spotify:album:0vO0b1AvY49CPQyVisJLj0       250373
# 6   spotify:album:1RM6MGv6bcl6NrAG8PGoZk       223440
# 7   spotify:album:5x8e8UcCeOgrOzSnDGuPye       225560
# 8   spotify:album:283NWqNsCA9GwVHrJk59CG       271333
# 9   spotify:album:1UsmQ3bpJTyK6ygoOOjG1r       235213
# 10  spotify:album:2yboV2QBcVGEhcRlYuPpDT       242293
# 11  spotify:album:6022khQj4Fsvvse8f3A4lF       211693
# 12  spotify:album:2gidE8vgVOkYufANjuvj3S       214226
# 13  spotify:album:2tDCfKFy2YW9N0IwNSRdOJ       216880
# 14  spotify:album:0j1qzjaJmsF1FkcICf3hRu       192213
# 15  spotify:album:4cVVEOXyUaWo7vlDWIkKsI       256426
# 16  spotify:album:7h6XeTzy0SRXDrFJeA9gO7       204000
# 17  spotify:album:49gaz5rhWWgqCw61M9700v       229866
# 18  spotify:album:3MJHoQUI828kmB6IpjejbW       210453
# 19  spotify:album:283NWqNsCA9GwVHrJk59CG       230200
# 20  spotify:album:5NYcTXrRZHxNyRKVOd0vs1       292306
# 21  spotify:album:1bNyYpkDRovmErm4QeDrpJ       272533
# 22  spotify:album:3Q7xpHmP8k3HryE0LQdIk0       193042
# 23  spotify:album:7gZilZGYr8M7UwEeYvdAKZ       234146
# 24  spotify:album:49gaz5rhWWgqCw61M9700v       229040
# 25  spotify:album:20RAjvZ9LX2FDuDU8RDuIl       201960
# 26  spotify:album:3vgVsm9GY3i39fZ7b1sqV5       219773
# 27  spotify:album:5DvuKZTzEKjm0oUuhP237C       199120
# 28  spotify:album:0aVJmVAeEx78nAA1rAKYf7       221253
# 29  spotify:album:6dTn9vJSxVTIGm4Cu5dH4x       232000
# 30  spotify:album:64aKkqxc3Ur2LYIKeS5osS       202066
# 31  spotify:album:4WqgusSAgXkrjbXzqdBY68       206520
# 32  spotify:album:44hyrGuZKAvITbmrlhryf8       182306
# 33  spotify:album:1UtE4zAlSE2TlKmTFgrTg5       277106
# 34  spotify:album:5peRwC6pQh8eaoIPtvmmOB       187133
# 35  spotify:album:1nv3KEXZPmcwOXMoLTs1vn       234360
# 36  spotify:album:1rG5TDs3jYh6OU753I54CI       229106
# 37  spotify:album:1Lymt1abGCr3J06bbnmWca       203760
# 38  spotify:album:4undIeGmofnAYKhnDclN1w       222586
# 39  spotify:album:1fF8kYX49s5Ufv4XEY5sjW       168000
# 40  spotify:album:0ylxpXE00fVxh6d60tevT8       229360
# 41  spotify:album:6gdLfnf2vdNlMTyhJHaDLs       220920
# 42  spotify:album:3PWEGZ6CYvXRnr0JCECsDe       193653
# 43  spotify:album:6gdLfnf2vdNlMTyhJHaDLs       213973
# 44  spotify:album:7D6BFTArx2ajtkKRVXIKO2       237493
# 45  spotify:album:2kNznk4KDkYXifzOAUDoXN       201230
# 46  spotify:album:6SkirMQoL4QhnXOM5MH5El       190453
# 47  spotify:album:2tDCfKFy2YW9N0IwNSRdOJ       208333
# 48  spotify:album:6vykWEBzBfEKYJxEFR1AQl       189186
# 49  spotify:album:7851Vsjv3apS52sXUik6iF       242413
# 50  spotify:album:2F1hfUOuMnOxtSfrktL8VX       220133
# 51  spotify:album:4WqgusSAgXkrjbXzqdBY68       206520

# %%
playlist_tracks_df.shape
# Out:
# (1339962, 11)

# %% [markdown]
# To check the length of the longest string in the column (for VARCHAR())

# %%
import numpy as np

# %%
playlist_tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339962 entries, 0 to 1339961
# Data columns (total 11 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   playlist_id    1339962 non-null  int64
#  1   playlist_name  1339962 non-null  object
#  2   num_tracks     1339962 non-null  int64
#  3   track_pos      1339962 non-null  int64
#  4   track_name     1339955 non-null  object
#  5   track_uri      1339962 non-null  object
#  6   artist_name    1339960 non-null  object
#  7   artist_uri     1339962 non-null  object
#  8   album_name     1339962 non-null  object
#  9   album_uri      1339962 non-null  object
#  10  duration_ms    1339962 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 112.5+ MB

# %% [markdown]
# list of column names with text :['playlist_name', 'track_name', 'track_uri', 'artist_name', 'artist_uri', 'album_name', 'album_uri']

# %%
# finds the longest string(s) in a column
lengths = playlist_tracks_df["album_uri"].str.len()
argmax = np.where(lengths == lengths.max())[0]
playlist_tracks_df.iloc[argmax]['album_uri']
# Out:
# 0          spotify:album:6vV5UrXcfyQD1wu4Qo2I9K
# 1          spotify:album:0z7pVBGOD7HCIB7S8eLkLI
# 2          spotify:album:25hVFAxTlDvXbx2X2QkUkE
# 3          spotify:album:6QPkyl04rXwTGlGlcYaRoW
# 4          spotify:album:6NmFmPX56pcLBOFMhIiKvF
#                            ...
# 7322474    spotify:album:0o2oPAxKGui4tvrrNgDtkc
# 7322475    spotify:album:40V7QExJNlpQZaxZf1JTF5
# 7322476    spotify:album:6YXkbmsVABrzPBO6Vknj2P
# 7322477    spotify:album:2ObOh59P7oEmLSvqSUjXxc
# 7322478    spotify:album:2LYwooMTH1iJeBvWyXXWUf
# Name: album_uri, Length: 7322479, dtype: object

# %%
# check the length of a string in a given playlist
len(playlist_tracks_df.iloc[7322474]['album_uri'])
# Out:
# 36

# %% [markdown]
# max length:
# name: 75
# track_name: 253
# track_uri: 32
# artist_name: 267
# artist_uri: 37
# album_name: 286
# album_uri: 36

# %% [markdown]
# ****************************************
