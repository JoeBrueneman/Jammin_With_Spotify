# %% [markdown]
# # Loading Data From PostgressSQL

# %%
# Import the required libraries and dependencies
import pandas as pd
import hvplot.pandas
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a782a5d5-f679-4aa9-9dcd-5c67cea4372b" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"c4b7f943-9a5b-415d-bd0e-2b3bc4057934":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"84a32971da9d4582b942ff71a03ff53c","client_comm_id":"334554766e79475393ae9a9347ec1e8b"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"c4b7f943-9a5b-415d-bd0e-2b3bc4057934","roots":{"p1002":"a782a5d5-f679-4aa9-9dcd-5c67cea4372b"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ## Loading Track Features

# %%
from sqlalchemy import URL

url_object = URL.create(
    "postgresql",
    username="-----",
    password="-----",  
    host="------",
    database="-------",
)

# %%
from sqlalchemy import create_engine

conn = create_engine(url_object).connect()

# %%
# Request the `track_features` table 
tracks_df = pd.read_sql_table("track_features", conn)

# %%
# Check out `tracks_df`
tracks_df
# Out:
#          danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0               0.591   0.721    2    -7.960     1       0.0308      0.019700
# 1               0.399   0.955   11    -3.662     0       0.0822      0.002600
# 2               0.573   0.915    1    -3.658     1       0.0532      0.809000
# 3               0.492   0.801    2    -7.679     1       0.0357      0.008960
# 4               0.219   0.367    0    -9.696     0       0.0285      0.072600
# ...               ...     ...  ...       ...   ...          ...           ...
# 2214987         0.521   0.443    7    -8.528     0       0.0610      0.774000
# 2214988         0.633   0.943    1    -2.459     1       0.1250      0.019500
# 2214989         0.556   0.716    6   -10.431     0       0.0872      0.000144
# 2214990         0.240   0.303    2   -13.626     1       0.0294      0.738000
# 2214991         0.726   0.220    2   -12.270     1       0.0427      0.801000
#
#          instrumentalness  liveness  valence    tempo                      id  \
# 0                0.000244    0.1170   0.4340   94.053  6KaZC1JpPRq9CNZ3X8jBCM
# 1                0.376000    0.4250   0.6790  156.583  7hiqCnFcOBFAqZSf3AOY8a
# 2                0.304000    0.3240   0.7580  105.323  1SxVwlqUaz6PdQSqjclahn
# 3                0.000120    0.1870   0.4910   74.969  1XGX6lvmT464sVpJKTF3aV
# 4                0.000006    0.0832   0.1070  148.622  317d1IqYa8JhV8BGVDtgwZ
# ...                   ...       ...      ...      ...                     ...
# 2214987          0.000202    0.0359   0.4700  130.242  5tpFsLvMBaeDON1s1b1hQv
# 2214988          0.001060    0.0617   0.9370  122.544  66pasDZqv03zKaxEvaM06B
# 2214989          0.000009    0.3340   0.7520  147.611  1uOIgPtrlywUhBxzerwm6G
# 2214990          0.470000    0.1030   0.0823   99.405  3C9B1hqJ71tTxNjIjPl47Y
# 2214991          0.903000    0.0952   0.4690  101.940  20s3iOslBjQ6icWjk28Wf0
#
#                                     track_uri  \
# 0        spotify:track:6KaZC1JpPRq9CNZ3X8jBCM
# 1        spotify:track:7hiqCnFcOBFAqZSf3AOY8a
# 2        spotify:track:1SxVwlqUaz6PdQSqjclahn
# 3        spotify:track:1XGX6lvmT464sVpJKTF3aV
# 4        spotify:track:317d1IqYa8JhV8BGVDtgwZ
# ...                                       ...
# 2214987  spotify:track:5tpFsLvMBaeDON1s1b1hQv
# 2214988  spotify:track:66pasDZqv03zKaxEvaM06B
# 2214989  spotify:track:1uOIgPtrlywUhBxzerwm6G
# 2214990  spotify:track:3C9B1hqJ71tTxNjIjPl47Y
# 2214991  spotify:track:20s3iOslBjQ6icWjk28Wf0
#
#                                                 track_href  \
# 0        https://api.spotify.com/v1/tracks/6KaZC1JpPRq9...
# 1        https://api.spotify.com/v1/tracks/7hiqCnFcOBFA...
# 2        https://api.spotify.com/v1/tracks/1SxVwlqUaz6P...
# 3        https://api.spotify.com/v1/tracks/1XGX6lvmT464...
# 4        https://api.spotify.com/v1/tracks/317d1IqYa8Jh...
# ...                                                    ...
# 2214987  https://api.spotify.com/v1/tracks/5tpFsLvMBaeD...
# 2214988  https://api.spotify.com/v1/tracks/66pasDZqv03z...
# 2214989  https://api.spotify.com/v1/tracks/1uOIgPtrlywU...
# 2214990  https://api.spotify.com/v1/tracks/3C9B1hqJ71tT...
# 2214991  https://api.spotify.com/v1/tracks/20s3iOslBjQ6...
#
#                                               analysis_url  duration_ms  \
# 0        https://api.spotify.com/v1/audio-analysis/6KaZ...       246933
# 1        https://api.spotify.com/v1/audio-analysis/7hiq...       165549
# 2        https://api.spotify.com/v1/audio-analysis/1SxV...       230000
# 3        https://api.spotify.com/v1/audio-analysis/1XGX...       229600
# 4        https://api.spotify.com/v1/audio-analysis/317d...       274547
# ...                                                    ...          ...
# 2214987  https://api.spotify.com/v1/audio-analysis/5tpF...       242405
# 2214988  https://api.spotify.com/v1/audio-analysis/66pa...       204667
# 2214989  https://api.spotify.com/v1/audio-analysis/1uOI...       224760
# 2214990  https://api.spotify.com/v1/audio-analysis/3C9B...       149787
# 2214991  https://api.spotify.com/v1/audio-analysis/20s3...       127707
#
#          time_signature
# 0                     4
# 1                     4
# 2                     4
# 3                     4
# 4                     4
# ...                 ...
# 2214987               4
# 2214988               4
# 2214989               4
# 2214990               4
# 2214991               3
#
# [2214992 rows x 17 columns]

# %%
# Write `track_features_df` to csv file
tracks_df.to_csv('Resources/tracks.csv')

# %%
# Create `track_feature_num_df`, and retain only the numeric features
tracks_feature_df = tracks_df.copy()
tracks_feature_df.index = tracks_feature_df['track_uri']
tracks_feature_df = tracks_feature_df[['danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_ms','time_signature']]
tracks_feature_df.head()
# Out:
#                                       danceability  energy  key  loudness  \
# track_uri
# spotify:track:6KaZC1JpPRq9CNZ3X8jBCM         0.591   0.721    2    -7.960
# spotify:track:7hiqCnFcOBFAqZSf3AOY8a         0.399   0.955   11    -3.662
# spotify:track:1SxVwlqUaz6PdQSqjclahn         0.573   0.915    1    -3.658
# spotify:track:1XGX6lvmT464sVpJKTF3aV         0.492   0.801    2    -7.679
# spotify:track:317d1IqYa8JhV8BGVDtgwZ         0.219   0.367    0    -9.696
#
#                                       mode  speechiness  acousticness  \
# track_uri
# spotify:track:6KaZC1JpPRq9CNZ3X8jBCM     1       0.0308       0.01970
# spotify:track:7hiqCnFcOBFAqZSf3AOY8a     0       0.0822       0.00260
# spotify:track:1SxVwlqUaz6PdQSqjclahn     1       0.0532       0.80900
# spotify:track:1XGX6lvmT464sVpJKTF3aV     1       0.0357       0.00896
# spotify:track:317d1IqYa8JhV8BGVDtgwZ     0       0.0285       0.07260
#
#                                       instrumentalness  liveness  valence  \
# track_uri
# spotify:track:6KaZC1JpPRq9CNZ3X8jBCM          0.000244    0.1170    0.434
# spotify:track:7hiqCnFcOBFAqZSf3AOY8a          0.376000    0.4250    0.679
# spotify:track:1SxVwlqUaz6PdQSqjclahn          0.304000    0.3240    0.758
# spotify:track:1XGX6lvmT464sVpJKTF3aV          0.000120    0.1870    0.491
# spotify:track:317d1IqYa8JhV8BGVDtgwZ          0.000006    0.0832    0.107
#
#                                         tempo  duration_ms  time_signature
# track_uri
# spotify:track:6KaZC1JpPRq9CNZ3X8jBCM   94.053       246933               4
# spotify:track:7hiqCnFcOBFAqZSf3AOY8a  156.583       165549               4
# spotify:track:1SxVwlqUaz6PdQSqjclahn  105.323       230000               4
# spotify:track:1XGX6lvmT464sVpJKTF3aV   74.969       229600               4
# spotify:track:317d1IqYa8JhV8BGVDtgwZ  148.622       274547               4

# %%
# Write tracks_feature_df
tracks_feature_df.to_csv('Resources/tracks_feature.csv')

# %% [markdown]
# ## Loading Playlist Features

# %%
conn.close()
